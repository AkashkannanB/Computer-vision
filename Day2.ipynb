# %% [markdown]
# <a href="https://colab.research.google.com/github/AkashkannanB/Computer-vision/blob/main/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Core libraries

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt


# Dataset

from tensorflow.keras.datasets import cifar10



# To build neural network models Pretrained model

from tensorflow.keras.applications import MobileNetV2

# Pretrained CNN model

# Evaluation metrics

# Utilities

from sklearn.metrics import classification_report, confusion_matrix

import seaborn as sns # For better visualization

#(like heatmaps)

# %%
(x_train,y_train),(x_test,y_test) = cifar10.load_data()
print("train shape:",x_train.shape)
print("Test shape:",x_test.shape)
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 11s 0us/step
# train shape: (50000, 32, 32, 3)
# Test shape: (10000, 32, 32, 3)

# %%
# Normalize pixel values (0–255 -> 0–1)
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
data_augmentataion = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1)
])

# %%
base_model = MobileNetV2(input_shape=(32,32,3),
                        include_top=False,
                        weights='imagenet')
base_model.trainable = False
# Out:
# /tmp/ipykernel_4607/2138328753.py:1: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(input_shape=(32,32,3),
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
model = models.sequential([

])
